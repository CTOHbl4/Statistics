# %%
# https://ijassa.ipu.ru/index.php/ijassa/article/view/899/538


import random
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
import os
from pathlib import Path

from sem.generate_series import create_sde_process
from sem.sem.mixture_em_diff import NormalMixtureEM
from sem.sem.mixture_sem import MixtureSEM
from sem.sem.windows import find_window_size


class EMForecaster(nn.Module):
    def __init__(self, 
                 window_size: int,
                 n_components: int = 3,
                 hidden_dim: int = 64,
                 n_em_iters: int = 5):
        super().__init__()
        
        self.dwindow_size = window_size - 1
        self.window_size = window_size
        self.n_components = n_components
        negative_slope = 0.01

        self.em_layer = NormalMixtureEM(
            series_length=self.dwindow_size,
            n_components=n_components,
            n_sem_iters=n_em_iters
        )

        fusion_input_dim = n_components * self.dwindow_size + n_components * 5
        self.fusion = nn.Sequential(
            nn.Linear(fusion_input_dim, 2 * hidden_dim, bias=False),
            nn.LeakyReLU(negative_slope),
            nn.Linear(2 * hidden_dim, hidden_dim, bias=False),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_dim, 1, bias=False)
        )

        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_uniform_(module.weight, negative_slope)
                if module.bias is not None:
                    nn.init.zeros_(module.bias)

    def forward(self, X_window):

        dX1 = X_window[..., 1:] - X_window[..., :-1]
        g_ik, p_k, a_k, b_k = self.em_layer(dX1)

        attention_logits = -b_k
        attention_weights = nn.functional.softmax(attention_logits, dim=1)

        fusion_input = torch.cat([
            (g_ik * dX1.unsqueeze(-1)).flatten(1),
            a_k,
            b_k,
            p_k,
            attention_weights * a_k,
            b_k * b_k * p_k
        ], dim=1)
        forecast = X_window[..., -1] + self.fusion(fusion_input).squeeze(-1)
        
        return forecast
    
    def forward_multistep(self, windows: torch.Tensor, n_steps: int) -> torch.Tensor:
        """
        Autoregressive multi-step forecasting for stateless models.
        
        Args:
            windows: [batch_size, window_size] - input windows
            n_steps: number of steps to forecast
            
        Returns:
            predictions: [batch_size, n_steps]
        """
        forecasts = []
        for _ in range(n_steps):
            forecast = self.forward(windows)
            forecasts.append(forecast)

            windows = torch.cat([
                windows[:, 1:],
                forecast.unsqueeze(-1)
            ], dim=1)
        results = torch.stack(forecasts, dim=1)
        return results
    
    @torch.no_grad()
    def generate_forecast(self, idx: int, 
                         time_series: torch.Tensor,
                         n_test_steps: int,
                         window_size: int) -> torch.Tensor:
        """
        Generate forecast starting at given index.
        
        Args:
            idx: starting index (negative values count from end)
            time_series: full time series data
            n_test_steps: number of steps to forecast
            window_size: size of input window
            train_series: alias for time_series (for backward compatibility)
            
        Returns:
            predictions: forecast values
        """
        if idx < 0:
            idx = time_series.shape[-1] + idx
        idx += 1

        start_idx = idx - window_size
        ts = time_series[..., start_idx: idx]
        assert ts.shape[-1] == window_size, 'not enough data'

        if not isinstance(ts, torch.Tensor):
            ts = torch.tensor(ts, dtype=torch.float32)
        if ts.dim() == 1:
            ts = ts.unsqueeze(0)

        device = next(self.parameters()).device
        window = ts.to(device)

        preds = self.forward_multistep(window, n_test_steps)
        if ts.shape[0] == 1:
            preds = preds.squeeze(0)
            
        return preds


class SEMForecaster(nn.Module):
    def __init__(self, 
                 window_size: int,
                 sem_method,
                 n_components: int = 3,
                 hidden_dim: int = 64):
        super().__init__()
        
        self.dwindow_size = window_size - 1
        self.window_size = window_size
        self.n_components = n_components
        self.sem_method = sem_method
        negative_slope = 0.01

        fusion_input_dim = n_components * self.dwindow_size + n_components * 5
        self.fusion = nn.Sequential(
            nn.Linear(fusion_input_dim, 2 * hidden_dim, bias=False),
            nn.LeakyReLU(negative_slope),
            nn.Linear(2 * hidden_dim, hidden_dim, bias=False),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_dim, 1, bias=False)
        )

        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_uniform_(module.weight, negative_slope)
                if module.bias is not None:
                    nn.init.zeros_(module.bias)

    def forward(self, X_window, g_ik, p_k, a_k, b_k):
        dX1 = X_window[..., 1:] - X_window[..., :-1]

        attention_logits = -b_k
        attention_weights = nn.functional.softmax(attention_logits, dim=1)

        fusion_input = torch.cat([
            (g_ik * dX1.unsqueeze(-1)).flatten(1),
            a_k,
            b_k,
            p_k,
            attention_weights * a_k,
            b_k * b_k * p_k
        ], dim=1)
        forecast = X_window[..., -1] + self.fusion(fusion_input).squeeze(-1)
        
        return forecast

    def forward_multistep(self, windows: torch.Tensor, n_steps: int) -> torch.Tensor:
        """
        Autoregressive multi-step forecasting for stateless models.
        
        Args:
            windows: [batch_size, window_size] - input windows
            n_steps: number of steps to forecast
            
        Returns:
            predictions: [batch_size, n_steps]
        """
        forecasts = []
        for _ in range(n_steps):
            dwindows = windows[:, 1:] - windows[:, :-1]
            g_ik, w, mu, sigma = self.sem_method(dwindows)
            forecast = self.forward(windows, g_ik, w, mu, sigma)
            forecasts.append(forecast)

            windows = torch.cat([
                windows[:, 1:],
                forecast.unsqueeze(-1)
            ], dim=1)
        results = torch.stack(forecasts, dim=1)
        return results
    
    @torch.no_grad()
    def generate_forecast(self, idx: int, 
                         time_series: torch.Tensor,
                         n_test_steps: int,
                         window_size: int) -> torch.Tensor:
        """
        Generate forecast starting at given index.

        Args:
            idx: starting index (negative values count from end)
            time_series: full time series data
            n_test_steps: number of steps to forecast
            window_size: size of input window
            train_series: alias for time_series (for backward compatibility)

        Returns:
            predictions: forecast values
        """
        if idx < 0:
            idx = time_series.shape[-1] + idx
        idx += 1

        start_idx = idx - window_size
        ts = time_series[..., start_idx: idx]
        assert ts.shape[-1] == window_size, 'not enough data'

        if not isinstance(ts, torch.Tensor):
            ts = torch.tensor(ts, dtype=torch.float32)
        if ts.dim() == 1:
            ts = ts.unsqueeze(0)

        device = next(self.parameters()).device
        window = ts.to(device)

        preds = self.forward_multistep(window, n_test_steps)
        if ts.shape[0] == 1:
            preds = preds.squeeze(0)
            
        return preds

# %%
from time import time
import json

N_COMPONENTS = 3
TOL = 1e-4
TOL_TEST = 1e-4

class TimeSeriesDataset(Dataset):
    def __init__(self, time_series: np.ndarray, window_size, n_train_steps=1):
        super().__init__()
        self.ts = time_series
        self.n_train_steps = n_train_steps
        self.window_length = window_size

    def __len__(self):
        return len(self.ts) - self.window_length - self.n_train_steps

    def __getitem__(self, idx):
        idx_last = idx + self.window_length
        return self.ts[idx:idx_last], self.ts[idx_last: idx_last + self.n_train_steps]

class StaticMixtureTimeSeriesDataset(Dataset):
    def __init__(self, time_series: np.ndarray, window_size: int, comp_distr, n_train_steps=1):
        super().__init__()
        self.ts = time_series
        self.n_train_steps = n_train_steps
        self.window_length = window_size
        dwindow_size = window_size - 1
        sem = MixtureSEM(time_series[1:] - time_series[:-1], None, dwindow_size, n_components=N_COMPONENTS, comp_distr=comp_distr, tol=TOL)
        start = time()
        self.g, self.w, self.mu, self.sigma = sem.find_params()
        print(comp_distr, time() - start)

    def __len__(self):
        return self.g.shape[0] - 1

    def __getitem__(self, idx):
        idx_last = idx + self.window_length
        target = self.ts[idx_last: idx_last + self.n_train_steps]
        window = self.ts[idx:idx_last]

        return window, target, self.g[idx], self.w[idx], self.mu[idx], self.sigma[idx]


class MAPELoss(nn.Module):
    def __init__(self, eps=1e-8):
        super().__init__()
        self.eps = eps
    
    def forward(self, predictions, targets):
        mape = torch.abs(predictions - targets) / (torch.abs(targets) + self.eps)
        return mape.mean()


class WeightedLoss(nn.Module):
    def __init__(self, mape=0.1, mse=0.9, eps=1e-8):
        super().__init__()
        self.mape = MAPELoss(eps)
        self.mse = nn.MSELoss()
        self.mape_weight = mape
        self.mse_weight = mse

    def forward(self, predictions, targets):
        return self.mape_weight * self.mape(predictions, targets) + self.mse_weight * self.mse(predictions, targets)


class Trainer:
    def __init__(self, setup, time_series, window_size, len_train, log_path,
                 log_freq_batch=50, n_tests=100, n_test_steps=50, n_train_steps=1, eps=1e-8, device='cuda'):
        self.train_series = time_series[:len_train]
        self.eval_series = time_series[len_train:]
        self.dataloader = setup['dataloader']

        self.window_size = window_size
        self.n_epochs = 50
        self.n_tests = n_tests
        self.n_test_steps = n_test_steps
        self.model = setup['model'].to(device)
        self.optimizer = torch.optim.AdamW(self.model.parameters(), 1e-3)
        self.criterion = WeightedLoss()
        self.scheduler = torch.optim.lr_scheduler.LinearLR(
            self.optimizer, 1.0, 1e-6, self.n_epochs
        )

        self.loss_threshold = 0.01
        self.eps = eps
        self.device = device
        self.log_freq_batch = log_freq_batch
        self.log_path = log_path
        
        self.n_train_steps = n_train_steps

    @torch.no_grad()
    def validate(self):
        preds = self.model.generate_forecast(
            idx=-1,
            time_series=self.train_series,
            n_test_steps=self.n_test_steps,
            window_size=self.window_size
        ).cpu().numpy()
        target = self.eval_series[:self.n_test_steps]
        return preds, target
    
    @torch.no_grad()
    def evaluate_multistep(self, test_ids):
        preds = np.empty((self.n_tests + 1, self.n_test_steps))
        targets = np.empty((self.n_tests + 1, self.n_test_steps))
        for test in range(self.n_tests):
            idx = test_ids[test]
            target_idx = idx + 1
            pred = self.model.generate_forecast(
                idx=idx,
                time_series=self.train_series,
                n_test_steps=self.n_test_steps,
                window_size=self.window_size
            ).cpu()
            target = self.train_series[target_idx:target_idx + self.n_test_steps]
            preds[test, :] = pred.numpy()
            targets[test, :] = target
        return preds, targets

    def run(self, test_ids):
        epoch_train_time = 0
        epoch_val_time = 0
        start_full = time()
        for epoch in range(1, self.n_epochs + 1):
            self.model.train()
            start_train = time()
            avg_threshold = self.train_epoch(epoch)
            epoch_train_time += time() - start_train
            self.model.eval()

            start_test = time()
            preds, targets = self.evaluate_multistep(test_ids)
            pred, target = self.validate()
            epoch_val_time += time() - start_test
            preds[-1, :] = pred
            targets[-1, :] = target
            tests_results = np.stack([preds, targets], axis=-1)  # shape: [n_tests+1, n_steps, 2]
            
            np.save(self.log_path / f'epoch_{epoch}', tests_results)
            
            if avg_threshold < self.loss_threshold:
                break
        
        time_full = time() - start_full
        mean_train_time = epoch_train_time / epoch
        mean_test_time = epoch_val_time / epoch / (self.n_test_steps + 1) / (self.n_tests)

        json.dump(
                {
                    'full_time': float(time_full),
                    'epoch_train_time': float(mean_train_time),
                    'epoch_test_time_one_step': float(mean_test_time),
                    'last_loss': float(avg_threshold)
                },
                open(self.log_path / 'times.json', 'w'),
                indent=2
            )
        print()
        print("Training completed!")
        return self.model
    
    def train_epoch(self, epoch_idx=0):
        print("Epoch:", epoch_idx)
        total_loss = 0.0

        for batch_idx, batch in enumerate(self.dataloader):
            target = batch.pop(1).to(self.device).float()
            windows = batch.pop(0).to(self.device).float()
            if self.n_train_steps == 1:
                target = target.squeeze(-1)

            self.optimizer.zero_grad()

            if self.n_train_steps == 1:
                results = self.model.forward(windows, *batch)
                if isinstance(results, tuple):
                    results = results[0]
            else:
                results = self.model.forward_multistep(windows, self.n_train_steps)

            loss = self.criterion(results, target)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=0.5)
            self.optimizer.step()

            total_loss += loss.item()

            if batch_idx % self.log_freq_batch == 0:
                basic_metrics = self.compute_basic_metrics(results, target)
                print("Batch IDX:", batch_idx)
                print(basic_metrics)
                print()
            if torch.isnan(loss):
                print(f"WARNING: NaN loss at batch {batch_idx}")
                break
        self.scheduler.step()

        avg_loss = total_loss / len(self.dataloader)
        print(f"Epoch {epoch_idx} - Average Loss: {avg_loss:.6f}")
        return avg_loss

    @torch.no_grad()
    def compute_basic_metrics(self, forecast, y_true):
        mae = torch.abs(forecast - y_true).mean().item()
        mse = torch.mean((forecast - y_true) ** 2).item()
        mape = torch.abs((forecast - y_true) / (y_true.abs() + self.eps)).mean().item() * 100
        return {'MAE': mae, 'MSE': mse, 'MAPE': mape}

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

def get_setups(train_series, window_size, batch_size):
    dwindow_size = window_size - 1
    sem_methods = {
        'normal': MixtureSEM(None, None, dwindow_size, n_components=N_COMPONENTS, comp_distr='normal', tol=TOL_TEST)._fit_batch,
        'student': MixtureSEM(None, None, dwindow_size, n_components=N_COMPONENTS, comp_distr='student', tol=TOL_TEST)._fit_batch,
        'laplace': MixtureSEM(None, None, dwindow_size, n_components=N_COMPONENTS, comp_distr='laplace', tol=TOL_TEST)._fit_batch
    }

    sem_dataloaders = {
        distr: DataLoader(StaticMixtureTimeSeriesDataset(train_series,
                                                         window_size,
                                                         distr),
                          batch_size,
                          shuffle=True)
        for distr in sem_methods
    }
    sem_dataloaders['normal_diff'] = DataLoader(TimeSeriesDataset(train_series, window_size), batch_size, shuffle=True)

    models = [SEMForecaster(window_size, method, N_COMPONENTS, 64) for method in sem_methods.values()]
    models.append(EMForecaster(window_size, N_COMPONENTS, 64, 5))

    setups = []
    for distr, model in zip(sem_dataloaders.keys(), models):
        setups.append({
            'name': (f'SEM_{distr}' if 'diff' not in distr else f'EM_{distr}'),
            'model': model,
            'dataloader': sem_dataloaders[distr]
        })

    return setups

def create_experiment_folder(base_path="experiments", model_name=None, series_idx=None):
    """
    Create folder structure: experiments/<model_name>/<series_idx>/
    """
    if model_name is None:
        model_name = "default"
    if series_idx is None:
        series_idx = "0"
    
    exp_path = Path(base_path) / model_name / str(series_idx)
    exp_path.mkdir(parents=True, exist_ok=True)
    
    return exp_path

def generate_test_ids(window_size, train_series, n_tests, n_test_steps):
    res = []
    for _ in range(n_tests):
        res.append(random.randint(window_size, len(train_series) - 1 - n_test_steps))
    return res

# %%
n_tests = 10
series_length = 3200
train_length = 3000
alpha = 0.75
N_init = 5
N_add = 5
n_epoch_tests = 15
n_test_steps = 200
batch_size = 64

for test in range(n_tests):
    print('_' * 50)
    print(test)
    print('_' * 50)
    set_seed(10 * test)
    series = create_sde_process(series_length)['X']
    train_series = series[:train_length]
    *_, window_size = find_window_size(train_series[1:] - train_series[:-1], alpha, N_init, N_add)
    window_size += 1
    setups = get_setups(train_series, window_size, batch_size)
    test_ids = generate_test_ids(window_size, train_series, n_epoch_tests, n_test_steps)
    for setup in setups:
        set_seed(10 * test)
        print('_' * 50)
        print(setup['name'])
        print('_' * 50)

        log_path = create_experiment_folder(model_name=setup['name'], series_idx=test)
        if len(os.listdir(log_path)):
            print(log_path)
            continue
        trainer = Trainer(setup, series, window_size, train_length, log_path,
                          log_freq_batch=70, n_tests=n_epoch_tests, n_test_steps=n_test_steps, device='cuda')
        model = trainer.run(test_ids)
# Out:
# __________________________________________________
# 0
# __________________________________________________
# N = 5; Max ACF(1): 1.0
# N = 10; Max ACF(1): 0.9714626669883728
# N = 15; Max ACF(1): 0.8973427414894104
# N = 20; Max ACF(1): 0.8615346550941467
# N = 25; Max ACF(1): 0.8269753456115723
# N = 30; Max ACF(1): 0.8037227988243103
# N = 35; Max ACF(1): 0.796712338924408
# N = 40; Max ACF(1): 0.7947536110877991
# N = 45; Max ACF(1): 0.7923765778541565
# N = 50; Max ACF(1): 0.7715969085693359
# N = 55; Max ACF(1): 0.7685389518737793
# N = 60; Max ACF(1): 0.7699713706970215
# N = 65; Max ACF(1): 0.7635490894317627
# N = 70; Max ACF(1): 0.7643201947212219
# N = 75; Max ACF(1): 0.7623101472854614
# N = 80; Max ACF(1): 0.7507982850074768
# N = 85; Max ACF(1): 0.7455227375030518
# Found window length: 85
# normal 0.020441293716430664
# student 0.1472158432006836
# laplace 0.0594632625579834
# __________________________________________________
# SEM_normal
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 1.3985342979431152, 'MSE': 3.9384307861328125, 'MAPE': 13.078580796718597}
#
# Epoch 1 - Average Loss: 1.954591
# Epoch: 2
# Batch IDX: 0
# {'MAE': 0.8308826088905334, 'MSE': 1.1450425386428833, 'MAPE': 6.280709803104401}
#
# Epoch 2 - Average Loss: 1.466039
# Epoch: 3
# Batch IDX: 0
# {'MAE': 0.8940143585205078, 'MSE': 1.3675748109817505, 'MAPE': 2.9232269152998924}
#
# Epoch 3 - Average Loss: 1.208262
# Epoch: 4
# Batch IDX: 0
# {'MAE': 0.8696128129959106, 'MSE': 1.4527403116226196, 'MAPE': 25.1274973154068}
#
# Epoch 4 - Average Loss: 0.965981
# Epoch: 5
# Batch IDX: 0
# {'MAE': 0.6914061307907104, 'MSE': 0.9352800846099854, 'MAPE': 1.9095281139016151}
#
# Epoch 5 - Average Loss: 0.758373
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.48342469334602356, 'MSE': 0.36404120922088623, 'MAPE': 2.18855831772089}
#
# Epoch 6 - Average Loss: 0.567531
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.45211395621299744, 'MSE': 0.33537083864212036, 'MAPE': 0.7903221994638443}
#
# Epoch 7 - Average Loss: 0.418149
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.5318099856376648, 'MSE': 0.5053672790527344, 'MAPE': 2.965157851576805}
#
# Epoch 8 - Average Loss: 0.311702
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.4191029369831085, 'MSE': 0.3082566261291504, 'MAPE': 1.3409893028438091}
#
# Epoch 9 - Average Loss: 0.238664
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.28104668855667114, 'MSE': 0.15040633082389832, 'MAPE': 1.83789674192667}
#
# Epoch 10 - Average Loss: 0.197503
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.25303030014038086, 'MSE': 0.10589154064655304, 'MAPE': 0.7045834790915251}
#
# Epoch 11 - Average Loss: 0.149437
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.26218536496162415, 'MSE': 0.12208472937345505, 'MAPE': 1.0034864768385887}
#
# Epoch 12 - Average Loss: 0.134819
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.2240101397037506, 'MSE': 0.0976923406124115, 'MAPE': 0.7908770814538002}
#
# Epoch 13 - Average Loss: 0.114606
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.20635032653808594, 'MSE': 0.07221749424934387, 'MAPE': 0.8680684491991997}
#
# Epoch 14 - Average Loss: 0.097466
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.17118479311466217, 'MSE': 0.06937851011753082, 'MAPE': 0.3525996347889304}
#
# Epoch 15 - Average Loss: 0.086367
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.18727123737335205, 'MSE': 0.08547893166542053, 'MAPE': 0.5850978195667267}
#
# Epoch 16 - Average Loss: 0.075506
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.18222765624523163, 'MSE': 0.05740842595696449, 'MAPE': 0.9434489533305168}
#
# Epoch 17 - Average Loss: 0.072900
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.16980822384357452, 'MSE': 0.06260596960783005, 'MAPE': 1.2382827699184418}
#
# Epoch 18 - Average Loss: 0.060406
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.14346471428871155, 'MSE': 0.03487047553062439, 'MAPE': 0.3862877609208226}
#
# Epoch 19 - Average Loss: 0.057386
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.13052572309970856, 'MSE': 0.02792934700846672, 'MAPE': 0.4322722088545561}
#
# Epoch 20 - Average Loss: 0.047310
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.12440970540046692, 'MSE': 0.034270890057086945, 'MAPE': 0.291837053373456}
#
# Epoch 21 - Average Loss: 0.056066
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.1612222045660019, 'MSE': 0.05772833153605461, 'MAPE': 0.3922572825103998}
#
# Epoch 22 - Average Loss: 0.040832
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.17098495364189148, 'MSE': 0.059747952967882156, 'MAPE': 0.414014607667923}
#
# Epoch 23 - Average Loss: 0.048161
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.12793053686618805, 'MSE': 0.029898956418037415, 'MAPE': 0.5605654790997505}
#
# Epoch 24 - Average Loss: 0.035141
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.1306035965681076, 'MSE': 0.03529444336891174, 'MAPE': 0.3300831187516451}
#
# Epoch 25 - Average Loss: 0.040653
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.06914538890123367, 'MSE': 0.00871189683675766, 'MAPE': 0.1907762372866273}
#
# Epoch 26 - Average Loss: 0.029980
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.1012573391199112, 'MSE': 0.020789138972759247, 'MAPE': 0.45891832560300827}
#
# Epoch 27 - Average Loss: 0.035029
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.10991280525922775, 'MSE': 0.021699490025639534, 'MAPE': 3.561226651072502}
#
# Epoch 28 - Average Loss: 0.022379
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.13075777888298035, 'MSE': 0.055829957127571106, 'MAPE': 0.293962424620986}
#
# Epoch 29 - Average Loss: 0.027340
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.07402503490447998, 'MSE': 0.010507459752261639, 'MAPE': 0.6836267653852701}
#
# Epoch 30 - Average Loss: 0.023303
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.10543718934059143, 'MSE': 0.02447742410004139, 'MAPE': 0.2550838515162468}
#
# Epoch 31 - Average Loss: 0.021200
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.07132714986801147, 'MSE': 0.01007082685828209, 'MAPE': 0.2863236702978611}
#
# Epoch 32 - Average Loss: 0.019398
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.060610756278038025, 'MSE': 0.006610538810491562, 'MAPE': 0.12008077464997768}
#
# Epoch 33 - Average Loss: 0.019197
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.07110950350761414, 'MSE': 0.010700657963752747, 'MAPE': 0.22441726177930832}
#
# Epoch 34 - Average Loss: 0.014023
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.058522239327430725, 'MSE': 0.005343111231923103, 'MAPE': 0.14833820750936866}
#
# Epoch 35 - Average Loss: 0.015783
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.07471595704555511, 'MSE': 0.010401668958365917, 'MAPE': 0.4374354612082243}
#
# Epoch 36 - Average Loss: 0.009629
#
# Training completed!
# __________________________________________________
# SEM_student
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 1.695083498954773, 'MSE': 5.830961227416992, 'MAPE': 14.186140894889832}
#
# Epoch 1 - Average Loss: 1.949097
# Epoch: 2
# Batch IDX: 0
# {'MAE': 0.8038207292556763, 'MSE': 1.1783958673477173, 'MAPE': 3.7030700594186783}
#
# Epoch 2 - Average Loss: 1.430568
# Epoch: 3
# Batch IDX: 0
# {'MAE': 0.8593772053718567, 'MSE': 1.2454330921173096, 'MAPE': 2.768201380968094}
#
# Epoch 3 - Average Loss: 1.168674
# Epoch: 4
# Batch IDX: 0
# {'MAE': 0.7780384421348572, 'MSE': 1.1707894802093506, 'MAPE': 137.59171962738037}
#
# Epoch 4 - Average Loss: 0.961865
# Epoch: 5
# Batch IDX: 0
# {'MAE': 0.7381951808929443, 'MSE': 1.0012946128845215, 'MAPE': 1.9115746021270752}
#
# Epoch 5 - Average Loss: 0.765180
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.4675388038158417, 'MSE': 0.35185015201568604, 'MAPE': 1.2407438829541206}
#
# Epoch 6 - Average Loss: 0.591799
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.5562562942504883, 'MSE': 0.5221849679946899, 'MAPE': 0.9529322385787964}
#
# Epoch 7 - Average Loss: 0.457671
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.5285613536834717, 'MSE': 0.503746747970581, 'MAPE': 2.476884052157402}
#
# Epoch 8 - Average Loss: 0.341051
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.444463849067688, 'MSE': 0.32025477290153503, 'MAPE': 2.938403934240341}
#
# Epoch 9 - Average Loss: 0.271684
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.32753193378448486, 'MSE': 0.1546928584575653, 'MAPE': 1.2683809734880924}
#
# Epoch 10 - Average Loss: 0.223503
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.2795012295246124, 'MSE': 0.1709386110305786, 'MAPE': 0.744563527405262}
#
# Epoch 11 - Average Loss: 0.188630
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.32850754261016846, 'MSE': 0.2293328046798706, 'MAPE': 1.3025837019085884}
#
# Epoch 12 - Average Loss: 0.158342
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.237541064620018, 'MSE': 0.10357619822025299, 'MAPE': 0.8733323775231838}
#
# Epoch 13 - Average Loss: 0.128982
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.2474627047777176, 'MSE': 0.12696343660354614, 'MAPE': 0.9798845276236534}
#
# Epoch 14 - Average Loss: 0.118406
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.24487008154392242, 'MSE': 0.14476746320724487, 'MAPE': 0.47881007194519043}
#
# Epoch 15 - Average Loss: 0.097770
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.20254451036453247, 'MSE': 0.08575305342674255, 'MAPE': 0.7639759220182896}
#
# Epoch 16 - Average Loss: 0.087638
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.20714034140110016, 'MSE': 0.0914168432354927, 'MAPE': 0.5967847071588039}
#
# Epoch 17 - Average Loss: 0.075593
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.20058514177799225, 'MSE': 0.07650317251682281, 'MAPE': 1.4118300750851631}
#
# Epoch 18 - Average Loss: 0.074379
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.1656782031059265, 'MSE': 0.05423887446522713, 'MAPE': 0.42667901143431664}
#
# Epoch 19 - Average Loss: 0.062968
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.12096283584833145, 'MSE': 0.02876194193959236, 'MAPE': 0.45541306026279926}
#
# Epoch 20 - Average Loss: 0.061330
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.18067596852779388, 'MSE': 0.06759236007928848, 'MAPE': 0.37383614107966423}
#
# Epoch 21 - Average Loss: 0.053246
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.15481416881084442, 'MSE': 0.048658858984708786, 'MAPE': 0.4279572516679764}
#
# Epoch 22 - Average Loss: 0.048291
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.12987829744815826, 'MSE': 0.029072843492031097, 'MAPE': 0.32312669791281223}
#
# Epoch 23 - Average Loss: 0.042263
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.1548749804496765, 'MSE': 0.04389866441488266, 'MAPE': 9.47614312171936}
#
# Epoch 24 - Average Loss: 0.044933
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.10104195773601532, 'MSE': 0.016303226351737976, 'MAPE': 0.3139777109026909}
#
# Epoch 25 - Average Loss: 0.037740
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.11567030847072601, 'MSE': 0.028125140815973282, 'MAPE': 0.2547654788941145}
#
# Epoch 26 - Average Loss: 0.035290
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.11013226211071014, 'MSE': 0.02104894630610943, 'MAPE': 0.5233052186667919}
#
# Epoch 27 - Average Loss: 0.029171
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.12422193586826324, 'MSE': 0.030107181519269943, 'MAPE': 4.918461665511131}
#
# Epoch 28 - Average Loss: 0.033926
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.11312417685985565, 'MSE': 0.0402938574552536, 'MAPE': 0.2075857948511839}
#
# Epoch 29 - Average Loss: 0.022640
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.09534318745136261, 'MSE': 0.02349149063229561, 'MAPE': 0.48009203746914864}
#
# Epoch 30 - Average Loss: 0.027452
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.08620274066925049, 'MSE': 0.01384088397026062, 'MAPE': 0.21413462236523628}
#
# Epoch 31 - Average Loss: 0.019702
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.07134565711021423, 'MSE': 0.011623486876487732, 'MAPE': 0.2519363071769476}
#
# Epoch 32 - Average Loss: 0.023464
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.08444136381149292, 'MSE': 0.013576868921518326, 'MAPE': 0.18350346945226192}
#
# Epoch 33 - Average Loss: 0.017488
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.08554978668689728, 'MSE': 0.013319320976734161, 'MAPE': 1.6431992873549461}
#
# Epoch 34 - Average Loss: 0.017133
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.0718269944190979, 'MSE': 0.009861020371317863, 'MAPE': 0.20661293528974056}
#
# Epoch 35 - Average Loss: 0.014139
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.06785407662391663, 'MSE': 0.008095905184745789, 'MAPE': 0.22173912730067968}
#
# Epoch 36 - Average Loss: 0.013717
# Epoch: 37
# Batch IDX: 0
# {'MAE': 0.07151180505752563, 'MSE': 0.014651622623205185, 'MAPE': 0.7383973337709904}
#
# Epoch 37 - Average Loss: 0.010321
# Epoch: 38
# Batch IDX: 0
# {'MAE': 0.05829739570617676, 'MSE': 0.006153908558189869, 'MAPE': 0.7628851570188999}
#
# Epoch 38 - Average Loss: 0.012010
# Epoch: 39
# Batch IDX: 0
# {'MAE': 0.04997553303837776, 'MSE': 0.0047648511826992035, 'MAPE': 0.5003885831683874}
#
# Epoch 39 - Average Loss: 0.007623
#
# Training completed!
# __________________________________________________
# SEM_laplace
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 1.5936628580093384, 'MSE': 5.538313865661621, 'MAPE': 13.24344128370285}
#
# Epoch 1 - Average Loss: 2.061030
# Epoch: 2
# Batch IDX: 0
# {'MAE': 0.8206213712692261, 'MSE': 1.1744461059570312, 'MAPE': 4.547359421849251}
#
# Epoch 2 - Average Loss: 1.385162
# Epoch: 3
# Batch IDX: 0
# {'MAE': 0.8284796476364136, 'MSE': 1.1397616863250732, 'MAPE': 4.050996899604797}
#
# Epoch 3 - Average Loss: 1.062614
# Epoch: 4
# Batch IDX: 0
# {'MAE': 0.8356106281280518, 'MSE': 1.2385540008544922, 'MAPE': 218.16322803497314}
#
# Epoch 4 - Average Loss: 0.819812
# Epoch: 5
# Batch IDX: 0
# {'MAE': 0.6575036644935608, 'MSE': 0.8239259719848633, 'MAPE': 1.5683842822909355}
#
# Epoch 5 - Average Loss: 0.606647
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.5056217312812805, 'MSE': 0.45890745520591736, 'MAPE': 2.4632394313812256}
#
# Epoch 6 - Average Loss: 0.433797
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.4054943025112152, 'MSE': 0.2872929871082306, 'MAPE': 0.6947994697839022}
#
# Epoch 7 - Average Loss: 0.311941
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.46903127431869507, 'MSE': 0.4014774560928345, 'MAPE': 2.06606462597847}
#
# Epoch 8 - Average Loss: 0.231324
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.2622055411338806, 'MSE': 0.1325986683368683, 'MAPE': 0.5175705067813396}
#
# Epoch 9 - Average Loss: 0.190541
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.2995622158050537, 'MSE': 0.18531963229179382, 'MAPE': 1.2709286995232105}
#
# Epoch 10 - Average Loss: 0.155336
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.23758183419704437, 'MSE': 0.10059678554534912, 'MAPE': 0.783502496778965}
#
# Epoch 11 - Average Loss: 0.121882
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.21017801761627197, 'MSE': 0.09350017458200455, 'MAPE': 0.9499081410467625}
#
# Epoch 12 - Average Loss: 0.122701
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.15770187973976135, 'MSE': 0.04490995779633522, 'MAPE': 0.5212175659835339}
#
# Epoch 13 - Average Loss: 0.105136
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.1594821810722351, 'MSE': 0.0436432808637619, 'MAPE': 1.1407449841499329}
#
# Epoch 14 - Average Loss: 0.094885
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.1966271996498108, 'MSE': 0.09065809100866318, 'MAPE': 0.4035754129290581}
#
# Epoch 15 - Average Loss: 0.092961
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.22704866528511047, 'MSE': 0.10963315516710281, 'MAPE': 0.8188926614820957}
#
# Epoch 16 - Average Loss: 0.072276
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.16004569828510284, 'MSE': 0.05725141614675522, 'MAPE': 0.4509752616286278}
#
# Epoch 17 - Average Loss: 0.070517
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.15991345047950745, 'MSE': 0.057992082089185715, 'MAPE': 0.559221301227808}
#
# Epoch 18 - Average Loss: 0.061023
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.14636409282684326, 'MSE': 0.04405108839273453, 'MAPE': 0.3990492317825556}
#
# Epoch 19 - Average Loss: 0.057966
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.10506299138069153, 'MSE': 0.019255120307207108, 'MAPE': 0.36146759521216154}
#
# Epoch 20 - Average Loss: 0.048038
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.10313275456428528, 'MSE': 0.017766477540135384, 'MAPE': 0.24974639527499676}
#
# Epoch 21 - Average Loss: 0.048138
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.13874630630016327, 'MSE': 0.046348802745342255, 'MAPE': 0.33749977592378855}
#
# Epoch 22 - Average Loss: 0.042065
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.16268247365951538, 'MSE': 0.10229405015707016, 'MAPE': 0.33143903128802776}
#
# Epoch 23 - Average Loss: 0.044184
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.11725294589996338, 'MSE': 0.03293507546186447, 'MAPE': 5.276471376419067}
#
# Epoch 24 - Average Loss: 0.040431
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.12339895963668823, 'MSE': 0.02616775408387184, 'MAPE': 0.3047156846150756}
#
# Epoch 25 - Average Loss: 0.034649
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.10164496302604675, 'MSE': 0.017503246665000916, 'MAPE': 0.29553049243986607}
#
# Epoch 26 - Average Loss: 0.031919
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.07855065166950226, 'MSE': 0.011595763266086578, 'MAPE': 0.5949459038674831}
#
# Epoch 27 - Average Loss: 0.028860
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.11279715597629547, 'MSE': 0.036992110311985016, 'MAPE': 3.408246487379074}
#
# Epoch 28 - Average Loss: 0.028653
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.10170397162437439, 'MSE': 0.034890659153461456, 'MAPE': 0.213518925011158}
#
# Epoch 29 - Average Loss: 0.024714
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.0759040042757988, 'MSE': 0.009651245549321175, 'MAPE': 0.3945350181311369}
#
# Epoch 30 - Average Loss: 0.024607
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.1074041873216629, 'MSE': 0.028728283941745758, 'MAPE': 0.2557225292548537}
#
# Epoch 31 - Average Loss: 0.021141
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.0686720758676529, 'MSE': 0.012173803523182869, 'MAPE': 0.22871731780469418}
#
# Epoch 32 - Average Loss: 0.019498
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.06638163328170776, 'MSE': 0.011699507012963295, 'MAPE': 0.13982427772134542}
#
# Epoch 33 - Average Loss: 0.016591
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.086713045835495, 'MSE': 0.01506974920630455, 'MAPE': 0.3829941153526306}
#
# Epoch 34 - Average Loss: 0.017279
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.049970149993896484, 'MSE': 0.004182439297437668, 'MAPE': 0.12135535944253206}
#
# Epoch 35 - Average Loss: 0.012524
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.0650160014629364, 'MSE': 0.007903803139925003, 'MAPE': 0.404543150216341}
#
# Epoch 36 - Average Loss: 0.014058
# Epoch: 37
# Batch IDX: 0
# {'MAE': 0.0471489354968071, 'MSE': 0.006781246978789568, 'MAPE': 0.6195366382598877}
#
# Epoch 37 - Average Loss: 0.008939
#
# Training completed!
# __________________________________________________
# EM_normal_diff
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 1.22641122341156, 'MSE': 2.4458584785461426, 'MAPE': 4.497547075152397}
#
# Epoch 1 - Average Loss: 1.935760
# Epoch: 2
# Batch IDX: 0
# {'MAE': 1.050181269645691, 'MSE': 1.829047679901123, 'MAPE': 2.018331363797188}
#
# Epoch 2 - Average Loss: 1.508446
# Epoch: 3
# Batch IDX: 0
# {'MAE': 0.8147369623184204, 'MSE': 1.2507773637771606, 'MAPE': 6.327325105667114}
#
# Epoch 3 - Average Loss: 1.285905
# Epoch: 4
# Batch IDX: 0
# {'MAE': 0.7906990051269531, 'MSE': 1.054145097732544, 'MAPE': 14.13692831993103}
#
# Epoch 4 - Average Loss: 1.100403
# Epoch: 5
# Batch IDX: 0
# {'MAE': 0.7975904941558838, 'MSE': 1.0130906105041504, 'MAPE': 1.7416402697563171}
#
# Epoch 5 - Average Loss: 0.934712
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.6230839490890503, 'MSE': 0.6429572105407715, 'MAPE': 2.9670201241970062}
#
# Epoch 6 - Average Loss: 0.770470
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.6413152813911438, 'MSE': 0.8371635675430298, 'MAPE': 3.392162173986435}
#
# Epoch 7 - Average Loss: 0.639042
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.5309568643569946, 'MSE': 0.49001261591911316, 'MAPE': 3.344660997390747}
#
# Epoch 8 - Average Loss: 0.512931
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.4190824329853058, 'MSE': 0.269465833902359, 'MAPE': 199.26174879074097}
#
# Epoch 9 - Average Loss: 0.422570
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.4770689010620117, 'MSE': 0.3924712538719177, 'MAPE': 2.8801586478948593}
#
# Epoch 10 - Average Loss: 0.345651
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.4333822727203369, 'MSE': 0.29286620020866394, 'MAPE': 1.0230187326669693}
#
# Epoch 11 - Average Loss: 0.287034
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.4204442501068115, 'MSE': 0.30120787024497986, 'MAPE': 0.7988729514181614}
#
# Epoch 12 - Average Loss: 0.243483
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.384960412979126, 'MSE': 0.29746437072753906, 'MAPE': 0.8644322864711285}
#
# Epoch 13 - Average Loss: 0.204944
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.38795846700668335, 'MSE': 0.2836311459541321, 'MAPE': 1.1038532480597496}
#
# Epoch 14 - Average Loss: 0.175077
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.30905744433403015, 'MSE': 0.1572619527578354, 'MAPE': 1.3881740160286427}
#
# Epoch 15 - Average Loss: 0.146537
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.24222543835639954, 'MSE': 0.10182137787342072, 'MAPE': 1.3249503448605537}
#
# Epoch 16 - Average Loss: 0.126395
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.2542959749698639, 'MSE': 0.14536793529987335, 'MAPE': 0.6628002040088177}
#
# Epoch 17 - Average Loss: 0.113202
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.19003552198410034, 'MSE': 0.05525193735957146, 'MAPE': 0.9167350828647614}
#
# Epoch 18 - Average Loss: 0.094562
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.2182312160730362, 'MSE': 0.09496666491031647, 'MAPE': 0.9258570149540901}
#
# Epoch 19 - Average Loss: 0.087544
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.18276181817054749, 'MSE': 0.06382908672094345, 'MAPE': 0.8828074671328068}
#
# Epoch 20 - Average Loss: 0.076657
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.2375582754611969, 'MSE': 0.09814110398292542, 'MAPE': 0.5051374435424805}
#
# Epoch 21 - Average Loss: 0.070323
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.19467857480049133, 'MSE': 0.06683637201786041, 'MAPE': 3.235745429992676}
#
# Epoch 22 - Average Loss: 0.060544
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.1948164403438568, 'MSE': 0.05730228126049042, 'MAPE': 1.0855009779334068}
#
# Epoch 23 - Average Loss: 0.060039
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.1468593180179596, 'MSE': 0.03333592414855957, 'MAPE': 0.6370930932462215}
#
# Epoch 24 - Average Loss: 0.054997
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.1889306604862213, 'MSE': 0.057654689997434616, 'MAPE': 1.0913817211985588}
#
# Epoch 25 - Average Loss: 0.054588
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.15149399638175964, 'MSE': 0.041818298399448395, 'MAPE': 0.34803831949830055}
#
# Epoch 26 - Average Loss: 0.041374
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.14567185938358307, 'MSE': 0.059694573283195496, 'MAPE': 0.38082199171185493}
#
# Epoch 27 - Average Loss: 0.041203
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.14407159388065338, 'MSE': 0.03795851394534111, 'MAPE': 2.3350579664111137}
#
# Epoch 28 - Average Loss: 0.035451
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.11448653042316437, 'MSE': 0.028188545256853104, 'MAPE': 0.2836210187524557}
#
# Epoch 29 - Average Loss: 0.036503
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.15207567811012268, 'MSE': 0.04138481616973877, 'MAPE': 0.5048302933573723}
#
# Epoch 30 - Average Loss: 0.028160
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.0883936882019043, 'MSE': 0.014037647284567356, 'MAPE': 0.25054612196981907}
#
# Epoch 31 - Average Loss: 0.026155
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.09807136654853821, 'MSE': 0.016792748123407364, 'MAPE': 0.2309227827936411}
#
# Epoch 32 - Average Loss: 0.025233
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.09446274489164352, 'MSE': 0.014480753801763058, 'MAPE': 0.44365953654050827}
#
# Epoch 33 - Average Loss: 0.022993
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.07456338405609131, 'MSE': 0.008572032675147057, 'MAPE': 0.3244629595428705}
#
# Epoch 34 - Average Loss: 0.019473
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.09151749312877655, 'MSE': 0.014326617121696472, 'MAPE': 0.6100693717598915}
#
# Epoch 35 - Average Loss: 0.020260
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.06542829424142838, 'MSE': 0.007211101707071066, 'MAPE': 0.17178715206682682}
#
# Epoch 36 - Average Loss: 0.013993
# Epoch: 37
# Batch IDX: 0
# {'MAE': 0.055124565958976746, 'MSE': 0.005017560441046953, 'MAPE': 0.09866193868219852}
#
# Epoch 37 - Average Loss: 0.014666
# Epoch: 38
# Batch IDX: 0
# {'MAE': 0.07112927734851837, 'MSE': 0.009315520524978638, 'MAPE': 0.25639834348112345}
#
# Epoch 38 - Average Loss: 0.011549
# Epoch: 39
# Batch IDX: 0
# {'MAE': 0.0733962431550026, 'MSE': 0.009215591475367546, 'MAPE': 0.30921970028430223}
#
# Epoch 39 - Average Loss: 0.010955
# Epoch: 40
# Batch IDX: 0
# {'MAE': 0.05782555416226387, 'MSE': 0.00635066581889987, 'MAPE': 0.3805669955909252}
#
# Epoch 40 - Average Loss: 0.008946
#
# Training completed!
# __________________________________________________
# 1
# __________________________________________________
# N = 5; Max ACF(1): 1.0
# N = 10; Max ACF(1): 0.982174813747406
# N = 15; Max ACF(1): 0.9210454821586609
# N = 20; Max ACF(1): 0.8981190323829651
# N = 25; Max ACF(1): 0.8618542551994324
# N = 30; Max ACF(1): 0.8287971019744873
# N = 35; Max ACF(1): 0.7991965413093567
# N = 40; Max ACF(1): 0.7910274267196655
# N = 45; Max ACF(1): 0.7761585116386414
# N = 50; Max ACF(1): 0.766106367111206
# N = 55; Max ACF(1): 0.750888466835022
# N = 60; Max ACF(1): 0.7185631394386292
# Found window length: 60
# normal 0.016486644744873047
# student 0.1327071189880371
# laplace 0.10779023170471191
# __________________________________________________
# SEM_normal
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 1.0922707319259644, 'MSE': 1.967980146408081, 'MAPE': 4.060560092329979}
#
# Epoch 1 - Average Loss: 1.934534
# Epoch: 2
# Batch IDX: 0
# {'MAE': 0.9694620370864868, 'MSE': 1.7326159477233887, 'MAPE': 3.116922080516815}
#
# Epoch 2 - Average Loss: 1.475800
# Epoch: 3
# Batch IDX: 0
# {'MAE': 1.0437887907028198, 'MSE': 1.7169665098190308, 'MAPE': 5.046973377466202}
#
# Epoch 3 - Average Loss: 1.260985
# Epoch: 4
# Batch IDX: 0
# {'MAE': 0.8018948435783386, 'MSE': 1.234489917755127, 'MAPE': 3.2515645027160645}
#
# Epoch 4 - Average Loss: 1.070989
# Epoch: 5
# Batch IDX: 0
# {'MAE': 0.7376071810722351, 'MSE': 0.8472794890403748, 'MAPE': 2.610652521252632}
#
# Epoch 5 - Average Loss: 0.898675
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.6967794299125671, 'MSE': 0.8756511807441711, 'MAPE': 2.013777010142803}
#
# Epoch 6 - Average Loss: 0.741913
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.5892605781555176, 'MSE': 0.58964604139328, 'MAPE': 5.4526012390851974}
#
# Epoch 7 - Average Loss: 0.599990
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.5171862840652466, 'MSE': 0.49172431230545044, 'MAPE': 1.738370954990387}
#
# Epoch 8 - Average Loss: 0.486311
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.4720873236656189, 'MSE': 0.38551008701324463, 'MAPE': 1.596769504249096}
#
# Epoch 9 - Average Loss: 0.383400
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.44928473234176636, 'MSE': 0.3395025134086609, 'MAPE': 1.7862308770418167}
#
# Epoch 10 - Average Loss: 0.307070
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.2957565188407898, 'MSE': 0.14672720432281494, 'MAPE': 1.3816922903060913}
#
# Epoch 11 - Average Loss: 0.247455
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.3274586796760559, 'MSE': 0.1749258041381836, 'MAPE': 1.113775558769703}
#
# Epoch 12 - Average Loss: 0.196807
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.31295347213745117, 'MSE': 0.17624017596244812, 'MAPE': 1.0396923869848251}
#
# Epoch 13 - Average Loss: 0.156889
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.2732473611831665, 'MSE': 0.12204117327928543, 'MAPE': 1.047644391655922}
#
# Epoch 14 - Average Loss: 0.128816
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.20729023218154907, 'MSE': 0.07236592471599579, 'MAPE': 0.8031690493226051}
#
# Epoch 15 - Average Loss: 0.107478
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.21091054379940033, 'MSE': 0.06828552484512329, 'MAPE': 1.1029135435819626}
#
# Epoch 16 - Average Loss: 0.090410
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.24813003838062286, 'MSE': 0.11913557350635529, 'MAPE': 1.7559276893734932}
#
# Epoch 17 - Average Loss: 0.075767
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.2097930610179901, 'MSE': 0.09724801778793335, 'MAPE': 0.9418160654604435}
#
# Epoch 18 - Average Loss: 0.067660
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.2101384997367859, 'MSE': 0.07267221808433533, 'MAPE': 1.1852847412228584}
#
# Epoch 19 - Average Loss: 0.055746
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.1387251317501068, 'MSE': 0.034346479922533035, 'MAPE': 0.5350827239453793}
#
# Epoch 20 - Average Loss: 0.052242
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.17778220772743225, 'MSE': 0.05508027225732803, 'MAPE': 0.5896983668208122}
#
# Epoch 21 - Average Loss: 0.048809
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.14997142553329468, 'MSE': 0.04141989350318909, 'MAPE': 0.6409470923244953}
#
# Epoch 22 - Average Loss: 0.042737
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.12976226210594177, 'MSE': 0.030938807874917984, 'MAPE': 0.4960206802934408}
#
# Epoch 23 - Average Loss: 0.038008
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.1443912386894226, 'MSE': 0.05243837833404541, 'MAPE': 0.5314171314239502}
#
# Epoch 24 - Average Loss: 0.035407
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.1344992220401764, 'MSE': 0.02770879492163658, 'MAPE': 0.5952698178589344}
#
# Epoch 25 - Average Loss: 0.031962
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.11287776380777359, 'MSE': 0.020944517105817795, 'MAPE': 0.8315177634358406}
#
# Epoch 26 - Average Loss: 0.028480
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.09981711953878403, 'MSE': 0.016908392310142517, 'MAPE': 0.4931777250021696}
#
# Epoch 27 - Average Loss: 0.025128
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.10458917915821075, 'MSE': 0.01748710311949253, 'MAPE': 0.5717942025512457}
#
# Epoch 28 - Average Loss: 0.022138
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.106840580701828, 'MSE': 0.02132667973637581, 'MAPE': 0.597004871815443}
#
# Epoch 29 - Average Loss: 0.021570
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.0749540776014328, 'MSE': 0.010469263419508934, 'MAPE': 0.36387217696756124}
#
# Epoch 30 - Average Loss: 0.018783
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.10651302337646484, 'MSE': 0.02118447981774807, 'MAPE': 0.5428696051239967}
#
# Epoch 31 - Average Loss: 0.018262
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.06401845812797546, 'MSE': 0.007098309695720673, 'MAPE': 0.1919143949635327}
#
# Epoch 32 - Average Loss: 0.015539
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.08578892797231674, 'MSE': 0.01408834382891655, 'MAPE': 0.3591594286262989}
#
# Epoch 33 - Average Loss: 0.013728
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.08133895695209503, 'MSE': 0.013757405802607536, 'MAPE': 0.45816036872565746}
#
# Epoch 34 - Average Loss: 0.013249
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.05871408432722092, 'MSE': 0.00650614220649004, 'MAPE': 0.27655058074742556}
#
# Epoch 35 - Average Loss: 0.010271
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.06498324871063232, 'MSE': 0.009138496592640877, 'MAPE': 0.3202668856829405}
#
# Epoch 36 - Average Loss: 0.010340
# Epoch: 37
# Batch IDX: 0
# {'MAE': 0.0565151572227478, 'MSE': 0.007050463929772377, 'MAPE': 0.37638992071151733}
#
# Epoch 37 - Average Loss: 0.008433
#
# Training completed!
# __________________________________________________
# SEM_student
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 1.4048054218292236, 'MSE': 2.9335153102874756, 'MAPE': 5.130382627248764}
#
# Epoch 1 - Average Loss: 1.880936
# Epoch: 2
# Batch IDX: 0
# {'MAE': 0.958092212677002, 'MSE': 1.6471624374389648, 'MAPE': 3.512326627969742}
#
# Epoch 2 - Average Loss: 1.457693
# Epoch: 3
# Batch IDX: 0
# {'MAE': 0.9934254288673401, 'MSE': 1.4852101802825928, 'MAPE': 4.918026179075241}
#
# Epoch 3 - Average Loss: 1.259379
# Epoch: 4
# Batch IDX: 0
# {'MAE': 0.8033397197723389, 'MSE': 1.1387312412261963, 'MAPE': 3.509923443198204}
#
# Epoch 4 - Average Loss: 1.086535
# Epoch: 5
# Batch IDX: 0
# {'MAE': 0.7798842787742615, 'MSE': 0.8817119598388672, 'MAPE': 3.227374330163002}
#
# Epoch 5 - Average Loss: 0.922713
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.7515515089035034, 'MSE': 0.9419584274291992, 'MAPE': 2.1089307963848114}
#
# Epoch 6 - Average Loss: 0.778791
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.6163908839225769, 'MSE': 0.6751165390014648, 'MAPE': 4.779797792434692}
#
# Epoch 7 - Average Loss: 0.643062
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.5291397571563721, 'MSE': 0.5506463050842285, 'MAPE': 1.6726665198802948}
#
# Epoch 8 - Average Loss: 0.520176
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.48480868339538574, 'MSE': 0.3973137140274048, 'MAPE': 1.6094449907541275}
#
# Epoch 9 - Average Loss: 0.429577
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.4541887640953064, 'MSE': 0.37791550159454346, 'MAPE': 1.6427507624030113}
#
# Epoch 10 - Average Loss: 0.346160
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.3383694291114807, 'MSE': 0.19412767887115479, 'MAPE': 1.2734463438391685}
#
# Epoch 11 - Average Loss: 0.278197
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.3062225580215454, 'MSE': 0.15776413679122925, 'MAPE': 1.0213077068328857}
#
# Epoch 12 - Average Loss: 0.225693
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.299641489982605, 'MSE': 0.14779730141162872, 'MAPE': 1.2041195295751095}
#
# Epoch 13 - Average Loss: 0.183210
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.3783775568008423, 'MSE': 0.22261887788772583, 'MAPE': 1.2880138121545315}
#
# Epoch 14 - Average Loss: 0.154659
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.2656797468662262, 'MSE': 0.12730473279953003, 'MAPE': 1.0433522053062916}
#
# Epoch 15 - Average Loss: 0.130591
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.24853655695915222, 'MSE': 0.10804802179336548, 'MAPE': 0.9279582649469376}
#
# Epoch 16 - Average Loss: 0.104960
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.2123304307460785, 'MSE': 0.06503919512033463, 'MAPE': 0.8342215791344643}
#
# Epoch 17 - Average Loss: 0.090914
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.21876786649227142, 'MSE': 0.09894954413175583, 'MAPE': 1.3688815757632256}
#
# Epoch 18 - Average Loss: 0.080200
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.17479553818702698, 'MSE': 0.06201229616999626, 'MAPE': 0.8465688675642014}
#
# Epoch 19 - Average Loss: 0.068321
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.1617351472377777, 'MSE': 0.05353240668773651, 'MAPE': 0.6660986226052046}
#
# Epoch 20 - Average Loss: 0.059690
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.15418221056461334, 'MSE': 0.044707298278808594, 'MAPE': 0.4755187314003706}
#
# Epoch 21 - Average Loss: 0.054827
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.1439262330532074, 'MSE': 0.037756577134132385, 'MAPE': 0.7538218516856432}
#
# Epoch 22 - Average Loss: 0.050547
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.15673242509365082, 'MSE': 0.03956471383571625, 'MAPE': 0.5874261260032654}
#
# Epoch 23 - Average Loss: 0.041652
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.1500454545021057, 'MSE': 0.04214509576559067, 'MAPE': 0.6504146847873926}
#
# Epoch 24 - Average Loss: 0.038293
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.14342132210731506, 'MSE': 0.0387311726808548, 'MAPE': 0.5362610332667828}
#
# Epoch 25 - Average Loss: 0.033628
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.13037389516830444, 'MSE': 0.02630619704723358, 'MAPE': 0.8566709235310555}
#
# Epoch 26 - Average Loss: 0.030605
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.11245355010032654, 'MSE': 0.02380712702870369, 'MAPE': 0.678911991417408}
#
# Epoch 27 - Average Loss: 0.029444
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.0812859982252121, 'MSE': 0.012110823765397072, 'MAPE': 0.5024928599596024}
#
# Epoch 28 - Average Loss: 0.025786
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.10720239579677582, 'MSE': 0.02554994449019432, 'MAPE': 0.42316121980547905}
#
# Epoch 29 - Average Loss: 0.023750
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.11985915899276733, 'MSE': 0.02541276440024376, 'MAPE': 0.6399788428097963}
#
# Epoch 30 - Average Loss: 0.022108
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.08756864815950394, 'MSE': 0.017349202185869217, 'MAPE': 0.3832513000816107}
#
# Epoch 31 - Average Loss: 0.019178
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.09373559802770615, 'MSE': 0.019697461277246475, 'MAPE': 0.2649642527103424}
#
# Epoch 32 - Average Loss: 0.016621
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.0675775334239006, 'MSE': 0.007963627576828003, 'MAPE': 0.259356084279716}
#
# Epoch 33 - Average Loss: 0.014958
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.08257053792476654, 'MSE': 0.013168098405003548, 'MAPE': 0.36610341630876064}
#
# Epoch 34 - Average Loss: 0.013817
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.06646782904863358, 'MSE': 0.0075630201026797295, 'MAPE': 0.28709040489047766}
#
# Epoch 35 - Average Loss: 0.011750
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.06800952553749084, 'MSE': 0.011917580850422382, 'MAPE': 0.3119389060884714}
#
# Epoch 36 - Average Loss: 0.010356
# Epoch: 37
# Batch IDX: 0
# {'MAE': 0.07400302588939667, 'MSE': 0.011791383847594261, 'MAPE': 0.3468284150585532}
#
# Epoch 37 - Average Loss: 0.009208
#
# Training completed!
# __________________________________________________
# SEM_laplace
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 1.0650660991668701, 'MSE': 1.906593918800354, 'MAPE': 3.8892805576324463}
#
# Epoch 1 - Average Loss: 1.823556
# Epoch: 2
# Batch IDX: 0
# {'MAE': 0.9345917701721191, 'MSE': 1.5643155574798584, 'MAPE': 3.074673004448414}
#
# Epoch 2 - Average Loss: 1.394575
# Epoch: 3
# Batch IDX: 0
# {'MAE': 0.9102696776390076, 'MSE': 1.2820172309875488, 'MAPE': 4.289136081933975}
#
# Epoch 3 - Average Loss: 1.160799
# Epoch: 4
# Batch IDX: 0
# {'MAE': 0.6958283185958862, 'MSE': 0.9505928754806519, 'MAPE': 2.771854028105736}
#
# Epoch 4 - Average Loss: 0.972605
# Epoch: 5
# Batch IDX: 0
# {'MAE': 0.7712748646736145, 'MSE': 0.8013705611228943, 'MAPE': 2.774618938565254}
#
# Epoch 5 - Average Loss: 0.796502
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.586198627948761, 'MSE': 0.5924065113067627, 'MAPE': 1.7807606607675552}
#
# Epoch 6 - Average Loss: 0.647626
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.6118820905685425, 'MSE': 0.617885172367096, 'MAPE': 6.470443308353424}
#
# Epoch 7 - Average Loss: 0.516373
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.48033028841018677, 'MSE': 0.39765486121177673, 'MAPE': 1.5382658690214157}
#
# Epoch 8 - Average Loss: 0.407907
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.38976627588272095, 'MSE': 0.3130350410938263, 'MAPE': 1.3593195006251335}
#
# Epoch 9 - Average Loss: 0.323029
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.3523486256599426, 'MSE': 0.2585950791835785, 'MAPE': 1.3274244964122772}
#
# Epoch 10 - Average Loss: 0.249386
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.28053542971611023, 'MSE': 0.13163284957408905, 'MAPE': 1.1496054008603096}
#
# Epoch 11 - Average Loss: 0.193581
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.29324740171432495, 'MSE': 0.1493600755929947, 'MAPE': 0.9543225169181824}
#
# Epoch 12 - Average Loss: 0.155022
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.30035722255706787, 'MSE': 0.18073973059654236, 'MAPE': 1.0680614039301872}
#
# Epoch 13 - Average Loss: 0.127219
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.24278056621551514, 'MSE': 0.10769344121217728, 'MAPE': 0.825850386172533}
#
# Epoch 14 - Average Loss: 0.106462
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.19068899750709534, 'MSE': 0.06813965737819672, 'MAPE': 0.6322272587567568}
#
# Epoch 15 - Average Loss: 0.088936
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.18448983132839203, 'MSE': 0.056649573147296906, 'MAPE': 0.728481961414218}
#
# Epoch 16 - Average Loss: 0.077693
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.24500088393688202, 'MSE': 0.1151685118675232, 'MAPE': 1.3896893709897995}
#
# Epoch 17 - Average Loss: 0.067444
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.2251967340707779, 'MSE': 0.11836650222539902, 'MAPE': 1.8983546644449234}
#
# Epoch 18 - Average Loss: 0.060241
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.16988493502140045, 'MSE': 0.05543625354766846, 'MAPE': 0.9840669110417366}
#
# Epoch 19 - Average Loss: 0.052253
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.16313113272190094, 'MSE': 0.051336612552404404, 'MAPE': 0.6759501993656158}
#
# Epoch 20 - Average Loss: 0.045652
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.12210604548454285, 'MSE': 0.030577359721064568, 'MAPE': 0.3991982899606228}
#
# Epoch 21 - Average Loss: 0.040199
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.12981683015823364, 'MSE': 0.026604846119880676, 'MAPE': 0.5447005853056908}
#
# Epoch 22 - Average Loss: 0.037642
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.1401004046201706, 'MSE': 0.0329425185918808, 'MAPE': 0.5143291316926479}
#
# Epoch 23 - Average Loss: 0.033981
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.12633997201919556, 'MSE': 0.035903483629226685, 'MAPE': 0.6784534081816673}
#
# Epoch 24 - Average Loss: 0.030658
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.12410500645637512, 'MSE': 0.02484823949635029, 'MAPE': 0.43983343057334423}
#
# Epoch 25 - Average Loss: 0.025547
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.11388176679611206, 'MSE': 0.037299755960702896, 'MAPE': 1.0694244876503944}
#
# Epoch 26 - Average Loss: 0.026112
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.10385925322771072, 'MSE': 0.023180684074759483, 'MAPE': 0.48769330605864525}
#
# Epoch 27 - Average Loss: 0.024129
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.11760491132736206, 'MSE': 0.03042888268828392, 'MAPE': 0.664606224745512}
#
# Epoch 28 - Average Loss: 0.023294
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.09799805283546448, 'MSE': 0.023555919528007507, 'MAPE': 0.47388989478349686}
#
# Epoch 29 - Average Loss: 0.019185
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.0940873995423317, 'MSE': 0.02894757129251957, 'MAPE': 0.4729415290057659}
#
# Epoch 30 - Average Loss: 0.018573
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.09521573781967163, 'MSE': 0.016225628554821014, 'MAPE': 0.5274594761431217}
#
# Epoch 31 - Average Loss: 0.016146
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.08004072308540344, 'MSE': 0.01363343559205532, 'MAPE': 0.2551317913457751}
#
# Epoch 32 - Average Loss: 0.014881
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.06887716799974442, 'MSE': 0.009731665253639221, 'MAPE': 0.3314854810014367}
#
# Epoch 33 - Average Loss: 0.012812
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.10748004168272018, 'MSE': 0.02133576199412346, 'MAPE': 0.6840940564870834}
#
# Epoch 34 - Average Loss: 0.010793
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.056256502866744995, 'MSE': 0.0057802218943834305, 'MAPE': 0.2822853159159422}
#
# Epoch 35 - Average Loss: 0.010142
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.06728717684745789, 'MSE': 0.008607914671301842, 'MAPE': 0.2942329505458474}
#
# Epoch 36 - Average Loss: 0.008832
#
# Training completed!
# __________________________________________________
# EM_normal_diff
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 0.9693178534507751, 'MSE': 1.5331047773361206, 'MAPE': 3.6817751824855804}
#
# Epoch 1 - Average Loss: 1.717025
# Epoch: 2
# Batch IDX: 0
# {'MAE': 0.9792073369026184, 'MSE': 1.6302518844604492, 'MAPE': 4.361001402139664}
#
# Epoch 2 - Average Loss: 1.443041
# Epoch: 3
# Batch IDX: 0
# {'MAE': 0.8299728035926819, 'MSE': 1.2444491386413574, 'MAPE': 3.352903202176094}
#
# Epoch 3 - Average Loss: 1.282525
# Epoch: 4
# Batch IDX: 0
# {'MAE': 0.9022125005722046, 'MSE': 1.286950945854187, 'MAPE': 2.7422983199357986}
#
# Epoch 4 - Average Loss: 1.137194
# Epoch: 5
# Batch IDX: 0
# {'MAE': 1.0206005573272705, 'MSE': 1.7116246223449707, 'MAPE': 5.757702887058258}
#
# Epoch 5 - Average Loss: 1.004693
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.8707131743431091, 'MSE': 1.2570111751556396, 'MAPE': 3.80934439599514}
#
# Epoch 6 - Average Loss: 0.883609
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.7085412740707397, 'MSE': 0.8257008194923401, 'MAPE': 2.6145005598664284}
#
# Epoch 7 - Average Loss: 0.771967
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.6071031093597412, 'MSE': 0.5912009477615356, 'MAPE': 2.1248582750558853}
#
# Epoch 8 - Average Loss: 0.683392
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.53899085521698, 'MSE': 0.45698776841163635, 'MAPE': 2.3900188505649567}
#
# Epoch 9 - Average Loss: 0.588284
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.5577448606491089, 'MSE': 0.49762648344039917, 'MAPE': 2.0235300064086914}
#
# Epoch 10 - Average Loss: 0.516786
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.6760388016700745, 'MSE': 0.8383872509002686, 'MAPE': 16.10500067472458}
#
# Epoch 11 - Average Loss: 0.445187
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.38902485370635986, 'MSE': 0.28110480308532715, 'MAPE': 1.290835626423359}
#
# Epoch 12 - Average Loss: 0.386602
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.41861313581466675, 'MSE': 0.31619828939437866, 'MAPE': 1.8775766715407372}
#
# Epoch 13 - Average Loss: 0.337251
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.5043504238128662, 'MSE': 0.36962875723838806, 'MAPE': 2.1253637969493866}
#
# Epoch 14 - Average Loss: 0.293957
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.3757837414741516, 'MSE': 0.2676016688346863, 'MAPE': 1.949799433350563}
#
# Epoch 15 - Average Loss: 0.255719
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.29579687118530273, 'MSE': 0.15704096853733063, 'MAPE': 0.9597781114280224}
#
# Epoch 16 - Average Loss: 0.219430
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.3123292922973633, 'MSE': 0.1383681446313858, 'MAPE': 1.313349138945341}
#
# Epoch 17 - Average Loss: 0.197468
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.3348647356033325, 'MSE': 0.18355876207351685, 'MAPE': 1.3775521889328957}
#
# Epoch 18 - Average Loss: 0.170365
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.20755203068256378, 'MSE': 0.06619402766227722, 'MAPE': 0.5968731362372637}
#
# Epoch 19 - Average Loss: 0.150304
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.24644023180007935, 'MSE': 0.10184463858604431, 'MAPE': 0.9466332383453846}
#
# Epoch 20 - Average Loss: 0.129464
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.2528035640716553, 'MSE': 0.1259174346923828, 'MAPE': 0.9273014962673187}
#
# Epoch 21 - Average Loss: 0.116656
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.23296809196472168, 'MSE': 0.0880887508392334, 'MAPE': 0.9310174733400345}
#
# Epoch 22 - Average Loss: 0.103200
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.20627842843532562, 'MSE': 0.06892576813697815, 'MAPE': 6.404225528240204}
#
# Epoch 23 - Average Loss: 0.088173
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.24777552485466003, 'MSE': 0.11111065745353699, 'MAPE': 1.020287163555622}
#
# Epoch 24 - Average Loss: 0.078017
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.19911110401153564, 'MSE': 0.06748858094215393, 'MAPE': 0.6648977287113667}
#
# Epoch 25 - Average Loss: 0.069807
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.2107679545879364, 'MSE': 0.0671575665473938, 'MAPE': 0.9077745489776134}
#
# Epoch 26 - Average Loss: 0.059966
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.1578701138496399, 'MSE': 0.03971646726131439, 'MAPE': 1.219305582344532}
#
# Epoch 27 - Average Loss: 0.054259
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.22854140400886536, 'MSE': 0.09513634443283081, 'MAPE': 1.042952947318554}
#
# Epoch 28 - Average Loss: 0.048499
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.14643293619155884, 'MSE': 0.03547528758645058, 'MAPE': 0.6635009311139584}
#
# Epoch 29 - Average Loss: 0.042154
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.14064398407936096, 'MSE': 0.034882210195064545, 'MAPE': 0.6593229249119759}
#
# Epoch 30 - Average Loss: 0.038084
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.14189769327640533, 'MSE': 0.0309748612344265, 'MAPE': 0.5864939652383327}
#
# Epoch 31 - Average Loss: 0.034106
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.09967971593141556, 'MSE': 0.015438796952366829, 'MAPE': 0.5299058742821217}
#
# Epoch 32 - Average Loss: 0.029885
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.11375649273395538, 'MSE': 0.020926881581544876, 'MAPE': 0.4570154473185539}
#
# Epoch 33 - Average Loss: 0.026831
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.11740348488092422, 'MSE': 0.023598477244377136, 'MAPE': 0.42898552492260933}
#
# Epoch 34 - Average Loss: 0.023911
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.08564068377017975, 'MSE': 0.01552063599228859, 'MAPE': 0.2541163004934788}
#
# Epoch 35 - Average Loss: 0.022036
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.08437064290046692, 'MSE': 0.01155431941151619, 'MAPE': 0.8185075595974922}
#
# Epoch 36 - Average Loss: 0.019002
# Epoch: 37
# Batch IDX: 0
# {'MAE': 0.1230698749423027, 'MSE': 0.033291496336460114, 'MAPE': 0.34168283455073833}
#
# Epoch 37 - Average Loss: 0.016966
# Epoch: 38
# Batch IDX: 0
# {'MAE': 0.07607072591781616, 'MSE': 0.009855149313807487, 'MAPE': 0.28165464755147696}
#
# Epoch 38 - Average Loss: 0.015094
# Epoch: 39
# Batch IDX: 0
# {'MAE': 0.07445143163204193, 'MSE': 0.010677041485905647, 'MAPE': 0.2991896588355303}
#
# Epoch 39 - Average Loss: 0.013094
# Epoch: 40
# Batch IDX: 0
# {'MAE': 0.07130858302116394, 'MSE': 0.009214457124471664, 'MAPE': 0.4232277628034353}
#
# Epoch 40 - Average Loss: 0.011951
# Epoch: 41
# Batch IDX: 0
# {'MAE': 0.07210498303174973, 'MSE': 0.008686017245054245, 'MAPE': 0.22409032098948956}
#
# Epoch 41 - Average Loss: 0.010182
# Epoch: 42
# Batch IDX: 0
# {'MAE': 0.08027911186218262, 'MSE': 0.015663450583815575, 'MAPE': 0.31677186489105225}
#
# Epoch 42 - Average Loss: 0.008655
#
# Training completed!
# __________________________________________________
# 2
# __________________________________________________
# N = 5; Max ACF(1): 1.0
# N = 10; Max ACF(1): 0.9843685626983643
# N = 15; Max ACF(1): 0.917119026184082
# N = 20; Max ACF(1): 0.8733877539634705
# N = 25; Max ACF(1): 0.866173505783081
# N = 30; Max ACF(1): 0.842941403388977
# N = 35; Max ACF(1): 0.8323345184326172
# N = 40; Max ACF(1): 0.8166887164115906
# N = 45; Max ACF(1): 0.798401951789856
# N = 50; Max ACF(1): 0.7965479493141174
# N = 55; Max ACF(1): 0.7795953750610352
# N = 60; Max ACF(1): 0.7407315969467163
# Found window length: 60
# normal 0.027186870574951172
# student 0.11789631843566895
# laplace 0.048572540283203125
# __________________________________________________
# SEM_normal
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 1.301393747329712, 'MSE': 2.6724367141723633, 'MAPE': 25.700324773788452}
#
# Epoch 1 - Average Loss: 1.794734
# Epoch: 2
# Batch IDX: 0
# {'MAE': 0.910331130027771, 'MSE': 1.4443988800048828, 'MAPE': 42.198216915130615}
#
# Epoch 2 - Average Loss: 1.400090
# Epoch: 3
# Batch IDX: 0
# {'MAE': 0.824799120426178, 'MSE': 1.0100363492965698, 'MAPE': 16.711057722568512}
#
# Epoch 3 - Average Loss: 1.196821
# Epoch: 4
# Batch IDX: 0
# {'MAE': 0.764134407043457, 'MSE': 0.883549690246582, 'MAPE': 7.566255331039429}
#
# Epoch 4 - Average Loss: 1.025662
# Epoch: 5
# Batch IDX: 0
# {'MAE': 0.5584449768066406, 'MSE': 0.5671404004096985, 'MAPE': 11.103452742099762}
#
# Epoch 5 - Average Loss: 0.853291
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.7482340931892395, 'MSE': 0.8899527788162231, 'MAPE': 38.06472420692444}
#
# Epoch 6 - Average Loss: 0.710158
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.6037181615829468, 'MSE': 0.660204291343689, 'MAPE': 6.6065095365047455}
#
# Epoch 7 - Average Loss: 0.582477
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.5030814409255981, 'MSE': 0.42108941078186035, 'MAPE': 4.216537624597549}
#
# Epoch 8 - Average Loss: 0.467743
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.4775281846523285, 'MSE': 0.36430859565734863, 'MAPE': 41.80166721343994}
#
# Epoch 9 - Average Loss: 0.375200
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.43988507986068726, 'MSE': 0.34981706738471985, 'MAPE': 9.006085991859436}
#
# Epoch 10 - Average Loss: 0.298273
# Epoch: 11
# Batch IDX: 0
# ...
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.19737452268600464, 'MSE': 0.07994881272315979, 'MAPE': 5.027750879526138}
#
# Epoch 29 - Average Loss: 0.072376
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.1229483038187027, 'MSE': 0.02861614339053631, 'MAPE': 0.8873047307133675}
#
# Epoch 30 - Average Loss: 0.064189
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.17696413397789001, 'MSE': 0.07104708254337311, 'MAPE': 1.2272180989384651}
#
# Epoch 31 - Average Loss: 0.056737
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.1681516468524933, 'MSE': 0.04561031609773636, 'MAPE': 1.0543448850512505}
#
# Epoch 32 - Average Loss: 0.054153
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.16323484480381012, 'MSE': 0.061338163912296295, 'MAPE': 4.0935225784778595}
#
# Epoch 33 - Average Loss: 0.045287
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.12000696361064911, 'MSE': 0.027636850252747536, 'MAPE': 0.8011026307940483}
#
# Epoch 34 - Average Loss: 0.041195
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.1462363600730896, 'MSE': 0.0390738770365715, 'MAPE': 0.9212984703481197}
#
# Epoch 35 - Average Loss: 0.037197
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.12306766211986542, 'MSE': 0.030957411974668503, 'MAPE': 0.7584678940474987}
#
# Epoch 36 - Average Loss: 0.032274
# Epoch: 37
# Batch IDX: 0
# {'MAE': 0.1302807629108429, 'MSE': 0.03561985120177269, 'MAPE': 1.1435102671384811}
#
# Epoch 37 - Average Loss: 0.032380
# Epoch: 38
# Batch IDX: 0
# {'MAE': 0.11084549874067307, 'MSE': 0.017776962369680405, 'MAPE': 0.7614145986735821}
#
# Epoch 38 - Average Loss: 0.025358
# Epoch: 39
# Batch IDX: 0
# {'MAE': 0.11695725470781326, 'MSE': 0.023937540128827095, 'MAPE': 0.8260704576969147}
#
# Epoch 39 - Average Loss: 0.022752
# Epoch: 40
# Batch IDX: 0
# {'MAE': 0.08734364062547684, 'MSE': 0.014699799939990044, 'MAPE': 0.628163805231452}
#
# Epoch 40 - Average Loss: 0.020453
# Epoch: 41
# Batch IDX: 0
# {'MAE': 0.08607201278209686, 'MSE': 0.013727333396673203, 'MAPE': 1.124987006187439}
#
# Epoch 41 - Average Loss: 0.017985
# Epoch: 42
# Batch IDX: 0
# {'MAE': 0.08081525564193726, 'MSE': 0.01074223406612873, 'MAPE': 0.5372676067054272}
#
# Epoch 42 - Average Loss: 0.015709
# Epoch: 43
# Batch IDX: 0
# {'MAE': 0.06638001650571823, 'MSE': 0.01140931062400341, 'MAPE': 0.6927827838808298}
#
# Epoch 43 - Average Loss: 0.013703
# Epoch: 44
# Batch IDX: 0
# {'MAE': 0.08728846162557602, 'MSE': 0.018307678401470184, 'MAPE': 0.6483805365860462}
#
# Epoch 44 - Average Loss: 0.012230
# Epoch: 45
# Batch IDX: 0
# {'MAE': 0.06426601111888885, 'MSE': 0.007210403215140104, 'MAPE': 0.7902003824710846}
#
# Epoch 45 - Average Loss: 0.010577
# Epoch: 46
# Batch IDX: 0
# {'MAE': 0.05056798458099365, 'MSE': 0.005067457910627127, 'MAPE': 2.0810723304748535}
#
# Epoch 46 - Average Loss: 0.009318
#
# Training completed!
# __________________________________________________
# SEM_laplace
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 1.9799203872680664, 'MSE': 6.902618408203125, 'MAPE': 15.527008473873138}
#
# Epoch 1 - Average Loss: 3.233162
# Epoch: 2
# Batch IDX: 0
# {'MAE': 1.156888723373413, 'MSE': 2.411135196685791, 'MAPE': 6.710018217563629}
#
# Epoch 2 - Average Loss: 2.357560
# Epoch: 3
# Batch IDX: 0
# {'MAE': 1.1988916397094727, 'MSE': 2.5074667930603027, 'MAPE': 8.640648424625397}
#
# Epoch 3 - Average Loss: 1.984673
# Epoch: 4
# Batch IDX: 0
# {'MAE': 1.0324435234069824, 'MSE': 2.005079746246338, 'MAPE': 8.24049562215805}
#
# Epoch 4 - Average Loss: 1.694222
# Epoch: 5
# Batch IDX: 0
# {'MAE': 1.0018608570098877, 'MSE': 1.9686576128005981, 'MAPE': 6.91915899515152}
#
# Epoch 5 - Average Loss: 1.447649
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.9027215838432312, 'MSE': 1.2726799249649048, 'MAPE': 8.47654640674591}
#
# Epoch 6 - Average Loss: 1.228376
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.8492817282676697, 'MSE': 1.2102454900741577, 'MAPE': 10.323822498321533}
#
# Epoch 7 - Average Loss: 1.003498
# Epoch: 8
# Batch IDX: 0
# {'MAE': 0.7862473726272583, 'MSE': 0.9676352143287659, 'MAPE': 22.0932736992836}
#
# Epoch 8 - Average Loss: 0.839297
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.7283294796943665, 'MSE': 0.8877514004707336, 'MAPE': 7.268534600734711}
#
# Epoch 9 - Average Loss: 0.695550
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.6065629124641418, 'MSE': 0.5326962471008301, 'MAPE': 6.454486399888992}
#
# Epoch 10 - Average Loss: 0.589175
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.5582435131072998, 'MSE': 0.48861461877822876, 'MAPE': 8.531473577022552}
#
# Epoch 11 - Average Loss: 0.468488
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.41129183769226074, 'MSE': 0.366939902305603, 'MAPE': 2.797863632440567}
#
# Epoch 12 - Average Loss: 0.397248
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.47631508111953735, 'MSE': 0.35563474893569946, 'MAPE': 3.0992206186056137}
#
# Epoch 13 - Average Loss: 0.321879
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.35668888688087463, 'MSE': 0.21259094774723053, 'MAPE': 5.286950618028641}
#
# Epoch 14 - Average Loss: 0.265934
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.3298693895339966, 'MSE': 0.23253628611564636, 'MAPE': 5.164438113570213}
#
# Epoch 15 - Average Loss: 0.231903
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.37586525082588196, 'MSE': 0.22682049870491028, 'MAPE': 4.379743710160255}
#
# Epoch 16 - Average Loss: 0.194866
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.31081634759902954, 'MSE': 0.1614050269126892, 'MAPE': 3.5691112279891968}
#
# Epoch 17 - Average Loss: 0.172819
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.31832313537597656, 'MSE': 0.15434125065803528, 'MAPE': 2.3681554943323135}
#
# Epoch 18 - Average Loss: 0.150133
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.19806551933288574, 'MSE': 0.05872856825590134, 'MAPE': 1.6896996647119522}
#
# Epoch 19 - Average Loss: 0.134393
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.24854084849357605, 'MSE': 0.109675332903862, 'MAPE': 4.161523655056953}
#
# Epoch 20 - Average Loss: 0.114847
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.24364914000034332, 'MSE': 0.13830527663230896, 'MAPE': 2.140737697482109}
#
# Epoch 21 - Average Loss: 0.101426
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.23274856805801392, 'MSE': 0.09698152542114258, 'MAPE': 2.3906338959932327}
#
# Epoch 22 - Average Loss: 0.090587
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.1748071312904358, 'MSE': 0.05188692361116409, 'MAPE': 1.7888709902763367}
#
# Epoch 23 - Average Loss: 0.079528
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.17105010151863098, 'MSE': 0.06416864693164825, 'MAPE': 1.5834182500839233}
#
# Epoch 24 - Average Loss: 0.071496
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.15633895993232727, 'MSE': 0.037068821489810944, 'MAPE': 10.166805237531662}
#
# Epoch 25 - Average Loss: 0.070701
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.19316264986991882, 'MSE': 0.11132858693599701, 'MAPE': 1.2176970951259136}
#
# Epoch 26 - Average Loss: 0.061824
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.15185943245887756, 'MSE': 0.04768211022019386, 'MAPE': 1.2682761065661907}
#
# Epoch 27 - Average Loss: 0.055909
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.13964520394802094, 'MSE': 0.034054532647132874, 'MAPE': 0.87110735476017}
#
# Epoch 28 - Average Loss: 0.050063
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.1325879693031311, 'MSE': 0.028685785830020905, 'MAPE': 1.4702221378684044}
#
# Epoch 29 - Average Loss: 0.048352
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.12416122108697891, 'MSE': 0.025272076949477196, 'MAPE': 1.009565033018589}
#
# Epoch 30 - Average Loss: 0.042401
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.15341205894947052, 'MSE': 0.0491536520421505, 'MAPE': 1.1471543461084366}
#
# Epoch 31 - Average Loss: 0.036128
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.15562176704406738, 'MSE': 0.06313050538301468, 'MAPE': 0.8109393529593945}
#
# Epoch 32 - Average Loss: 0.034570
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.13722527027130127, 'MSE': 0.05809611454606056, 'MAPE': 7.2979070246219635}
#
# Epoch 33 - Average Loss: 0.030043
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.10450270771980286, 'MSE': 0.02309204265475273, 'MAPE': 0.8049916476011276}
#
# Epoch 34 - Average Loss: 0.025630
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.13048464059829712, 'MSE': 0.035063523799180984, 'MAPE': 1.0182923637330532}
#
# Epoch 35 - Average Loss: 0.024883
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.10287746787071228, 'MSE': 0.02085854485630989, 'MAPE': 0.509642343968153}
#
# Epoch 36 - Average Loss: 0.022265
# Epoch: 37
# Batch IDX: 0
# {'MAE': 0.09693744778633118, 'MSE': 0.017795123159885406, 'MAPE': 1.0268237441778183}
#
# Epoch 37 - Average Loss: 0.019631
# Epoch: 38
# Batch IDX: 0
# {'MAE': 0.08911941945552826, 'MSE': 0.016984255984425545, 'MAPE': 0.5840307101607323}
#
# Epoch 38 - Average Loss: 0.016352
# Epoch: 39
# Batch IDX: 0
# {'MAE': 0.08379025757312775, 'MSE': 0.01614447496831417, 'MAPE': 0.5774523131549358}
#
# Epoch 39 - Average Loss: 0.014667
# Epoch: 40
# Batch IDX: 0
# {'MAE': 0.06283630430698395, 'MSE': 0.00759171973913908, 'MAPE': 0.5533835850656033}
#
# Epoch 40 - Average Loss: 0.012341
# Epoch: 41
# Batch IDX: 0
# {'MAE': 0.06553255021572113, 'MSE': 0.0068333446979522705, 'MAPE': 0.6928180810064077}
#
# Epoch 41 - Average Loss: 0.010883
# Epoch: 42
# Batch IDX: 0
# {'MAE': 0.06324788928031921, 'MSE': 0.006454372778534889, 'MAPE': 0.37447595968842506}
#
# Epoch 42 - Average Loss: 0.010272
# Epoch: 43
# Batch IDX: 0
# {'MAE': 0.0838833600282669, 'MSE': 0.024857159703969955, 'MAPE': 0.5913030356168747}
#
# Epoch 43 - Average Loss: 0.007374
#
# Training completed!
# __________________________________________________
# EM_normal_diff
# __________________________________________________
# Epoch: 1
# Batch IDX: 0
# {'MAE': 2.173570394515991, 'MSE': 8.278631210327148, 'MAPE': 21.751540899276733}
#
# Epoch 1 - Average Loss: 3.213764
# Epoch: 2
# Batch IDX: 0
# {'MAE': 1.4321315288543701, 'MSE': 3.2898218631744385, 'MAPE': 15.15260636806488}
#
# Epoch 2 - Average Loss: 2.524884
# Epoch: 3
# Batch IDX: 0
# {'MAE': 0.8957576751708984, 'MSE': 1.1977322101593018, 'MAPE': 5.327361822128296}
#
# Epoch 3 - Average Loss: 2.293248
# Epoch: 4
# Batch IDX: 0
# {'MAE': 1.2402451038360596, 'MSE': 2.6423792839050293, 'MAPE': 8.934321999549866}
#
# Epoch 4 - Average Loss: 2.108871
# Epoch: 5
# Batch IDX: 0
# {'MAE': 1.230439305305481, 'MSE': 2.393693447113037, 'MAPE': 13.059832155704498}
#
# Epoch 5 - Average Loss: 1.909734
# Epoch: 6
# Batch IDX: 0
# {'MAE': 0.9299612641334534, 'MSE': 1.3652689456939697, 'MAPE': 6.0339778661727905}
#
# Epoch 6 - Average Loss: 1.756029
# Epoch: 7
# Batch IDX: 0
# {'MAE': 0.8739129304885864, 'MSE': 1.1541574001312256, 'MAPE': 10.662908107042313}
#
# Epoch 7 - Average Loss: 1.597403
# Epoch: 8
# Batch IDX: 0
# {'MAE': 1.034364938735962, 'MSE': 1.7776408195495605, 'MAPE': 5.942477285861969}
#
# Epoch 8 - Average Loss: 1.458746
# Epoch: 9
# Batch IDX: 0
# {'MAE': 0.9257414937019348, 'MSE': 1.2545802593231201, 'MAPE': 20.89020311832428}
#
# Epoch 9 - Average Loss: 1.328678
# Epoch: 10
# Batch IDX: 0
# {'MAE': 0.8587967157363892, 'MSE': 1.210888385772705, 'MAPE': 8.297885954380035}
#
# Epoch 10 - Average Loss: 1.196959
# Epoch: 11
# Batch IDX: 0
# {'MAE': 0.9149265289306641, 'MSE': 1.2176094055175781, 'MAPE': 8.563831448554993}
#
# Epoch 11 - Average Loss: 1.118087
# Epoch: 12
# Batch IDX: 0
# {'MAE': 0.6613103151321411, 'MSE': 0.7294676899909973, 'MAPE': 7.021874189376831}
#
# Epoch 12 - Average Loss: 1.005030
# Epoch: 13
# Batch IDX: 0
# {'MAE': 0.9420154690742493, 'MSE': 1.402222752571106, 'MAPE': 6.349107623100281}
#
# Epoch 13 - Average Loss: 0.933911
# Epoch: 14
# Batch IDX: 0
# {'MAE': 0.7453393936157227, 'MSE': 0.9885386228561401, 'MAPE': 5.603685602545738}
#
# Epoch 14 - Average Loss: 0.846999
# Epoch: 15
# Batch IDX: 0
# {'MAE': 0.7056021094322205, 'MSE': 0.8185107111930847, 'MAPE': 9.375833719968796}
#
# Epoch 15 - Average Loss: 0.776108
# Epoch: 16
# Batch IDX: 0
# {'MAE': 0.6354591846466064, 'MSE': 0.7109981179237366, 'MAPE': 8.040526509284973}
#
# Epoch 16 - Average Loss: 0.715423
# Epoch: 17
# Batch IDX: 0
# {'MAE': 0.5888854265213013, 'MSE': 0.5265778303146362, 'MAPE': 4.992502927780151}
#
# Epoch 17 - Average Loss: 0.652074
# Epoch: 18
# Batch IDX: 0
# {'MAE': 0.6622931957244873, 'MSE': 0.7533066272735596, 'MAPE': 4.899110272526741}
#
# Epoch 18 - Average Loss: 0.587643
# Epoch: 19
# Batch IDX: 0
# {'MAE': 0.4933353364467621, 'MSE': 0.40446510910987854, 'MAPE': 13.824722170829773}
#
# Epoch 19 - Average Loss: 0.541091
# Epoch: 20
# Batch IDX: 0
# {'MAE': 0.603965163230896, 'MSE': 0.5660066604614258, 'MAPE': 5.639481917023659}
#
# Epoch 20 - Average Loss: 0.507158
# Epoch: 21
# Batch IDX: 0
# {'MAE': 0.4767457842826843, 'MSE': 0.36446887254714966, 'MAPE': 2.903835102915764}
#
# Epoch 21 - Average Loss: 0.455234
# Epoch: 22
# Batch IDX: 0
# {'MAE': 0.46988770365715027, 'MSE': 0.3567544221878052, 'MAPE': 3.2807014882564545}
#
# Epoch 22 - Average Loss: 0.415002
# Epoch: 23
# Batch IDX: 0
# {'MAE': 0.4812619984149933, 'MSE': 0.43798840045928955, 'MAPE': 2.8276294469833374}
#
# Epoch 23 - Average Loss: 0.381310
# Epoch: 24
# Batch IDX: 0
# {'MAE': 0.4718185067176819, 'MSE': 0.36682575941085815, 'MAPE': 4.570743441581726}
#
# Epoch 24 - Average Loss: 0.352652
# Epoch: 25
# Batch IDX: 0
# {'MAE': 0.37357181310653687, 'MSE': 0.23911021649837494, 'MAPE': 2.5708621367812157}
#
# Epoch 25 - Average Loss: 0.332856
# Epoch: 26
# Batch IDX: 0
# {'MAE': 0.471807599067688, 'MSE': 0.3548412322998047, 'MAPE': 3.5994619131088257}
#
# Epoch 26 - Average Loss: 0.310769
# Epoch: 27
# Batch IDX: 0
# {'MAE': 0.4631989598274231, 'MSE': 0.416878342628479, 'MAPE': 4.821646586060524}
#
# Epoch 27 - Average Loss: 0.278018
# Epoch: 28
# Batch IDX: 0
# {'MAE': 0.41907161474227905, 'MSE': 0.3021000623703003, 'MAPE': 2.6297589763998985}
#
# Epoch 28 - Average Loss: 0.262519
# Epoch: 29
# Batch IDX: 0
# {'MAE': 0.4034138321876526, 'MSE': 0.3484272360801697, 'MAPE': 3.8659922778606415}
#
# Epoch 29 - Average Loss: 0.241040
# Epoch: 30
# Batch IDX: 0
# {'MAE': 0.3184821903705597, 'MSE': 0.1917080283164978, 'MAPE': 2.3861145600676537}
#
# Epoch 30 - Average Loss: 0.229625
# Epoch: 31
# Batch IDX: 0
# {'MAE': 0.35454487800598145, 'MSE': 0.23528333008289337, 'MAPE': 1.9180204719305038}
#
# Epoch 31 - Average Loss: 0.206165
# Epoch: 32
# Batch IDX: 0
# {'MAE': 0.27748745679855347, 'MSE': 0.13614557683467865, 'MAPE': 1.959807239472866}
#
# Epoch 32 - Average Loss: 0.196634
# Epoch: 33
# Batch IDX: 0
# {'MAE': 0.2792590260505676, 'MSE': 0.151372492313385, 'MAPE': 1.6038138419389725}
#
# Epoch 33 - Average Loss: 0.180933
# Epoch: 34
# Batch IDX: 0
# {'MAE': 0.3119298815727234, 'MSE': 0.18799786269664764, 'MAPE': 1.9801191985607147}
#
# Epoch 34 - Average Loss: 0.165744
# Epoch: 35
# Batch IDX: 0
# {'MAE': 0.33029401302337646, 'MSE': 0.20494762063026428, 'MAPE': 3.0411304906010628}
#
# Epoch 35 - Average Loss: 0.157818
# Epoch: 36
# Batch IDX: 0
# {'MAE': 0.2728528082370758, 'MSE': 0.12786664068698883, 'MAPE': 2.3833226412534714}
#
# Epoch 36 - Average Loss: 0.142903
# Epoch: 37
# Batch IDX: 0
# {'MAE': 0.24037674069404602, 'MSE': 0.10782622545957565, 'MAPE': 2.7860127389431}
#
# Epoch 37 - Average Loss: 0.133251
# Epoch: 38
# Batch IDX: 0
# {'MAE': 0.28500160574913025, 'MSE': 0.13687817752361298, 'MAPE': 2.503974549472332}
#
# Epoch 38 - Average Loss: 0.126890
# Epoch: 39
# Batch IDX: 0
# {'MAE': 0.23167367279529572, 'MSE': 0.0886215791106224, 'MAPE': 1.9028229638934135}
#
# Epoch 39 - Average Loss: 0.117037
# Epoch: 40
# Batch IDX: 0
# {'MAE': 0.25923803448677063, 'MSE': 0.15868805348873138, 'MAPE': 2.1535679697990417}
#
# Epoch 40 - Average Loss: 0.111941
# Epoch: 41
# Batch IDX: 0
# {'MAE': 0.21111896634101868, 'MSE': 0.08094893395900726, 'MAPE': 1.0054058395326138}
#
# Epoch 41 - Average Loss: 0.107578
# Epoch: 42
# Batch IDX: 0
# {'MAE': 0.2686762511730194, 'MSE': 0.19137796759605408, 'MAPE': 1.4278393238782883}
#
# Epoch 42 - Average Loss: 0.099200
# Epoch: 43
# Batch IDX: 0
# {'MAE': 0.1877904087305069, 'MSE': 0.06443707644939423, 'MAPE': 1.0074013844132423}
#
# Epoch 43 - Average Loss: 0.096023
# Epoch: 44
# Batch IDX: 0
# {'MAE': 0.18642756342887878, 'MSE': 0.060105107724666595, 'MAPE': 1.098529901355505}
#
# Epoch 44 - Average Loss: 0.090424
# Epoch: 45
# Batch IDX: 0
# {'MAE': 0.22653520107269287, 'MSE': 0.0931900292634964, 'MAPE': 1.712920144200325}
#
# Epoch 45 - Average Loss: 0.084352
# Epoch: 46
# Batch IDX: 0
# {'MAE': 0.2625652551651001, 'MSE': 0.19143891334533691, 'MAPE': 1.4434091746807098}
#
# Epoch 46 - Average Loss: 0.081639
# Epoch: 47
# Batch IDX: 0
# {'MAE': 0.22968247532844543, 'MSE': 0.12365316599607468, 'MAPE': 2.328185550868511}
#
# Epoch 47 - Average Loss: 0.078953
# Epoch: 48
# Batch IDX: 0
# {'MAE': 0.1903865933418274, 'MSE': 0.08445273339748383, 'MAPE': 0.9981663897633553}
#
# Epoch 48 - Average Loss: 0.076005
# Epoch: 49
# Batch IDX: 0
# {'MAE': 0.16494965553283691, 'MSE': 0.0687548816204071, 'MAPE': 1.0078228078782558}
#
# Epoch 49 - Average Loss: 0.074681
# Epoch: 50
# Batch IDX: 0
# {'MAE': 0.21972841024398804, 'MSE': 0.09433656930923462, 'MAPE': 1.1839484795928001}
#
# Epoch 50 - Average Loss: 0.071021
#
# Training completed!
